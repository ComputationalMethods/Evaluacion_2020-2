# %% [markdown]
# # Oscilador de Duffing

# %% [markdown]
# ### Introducción conceptual

# %% [markdown]
# La ecuación de Duffing (u oscilador de Duffing ), que lleva el nombre de Georg Duffing (1861-1944), es una ecuación diferencial de segundo orden no lineal que se utiliza para modelar ciertos osciladores amortiguados y controlados . La ecuación está dada por:
#
# $\ddot{x} + \delta \dot{x} + \alpha x + \beta x^{3} = \gamma cos(\omega t)$
#
# donde la función (desconocida) $x = x(t)$ es el desplazamiento en el tiempo $t$, $\dot{x}$ es la primera derivada de $x$ con respecto al tiempo, es decir , la velocidad , y $\ddot{x}$ es la segunda derivada del tiempo de $x$, es decir, la aceleración . Los números $\delta, \alpha, \beta, \gamma$ y $\omega$ se dan constantes.
#
# La ecuación describe el movimiento de un oscilador amortiguado con un potencial más complejo que en el movimiento armónico simple (que corresponde al caso $\beta = \delta = 0$); en términos físicos, modela, por ejemplo, un péndulo elástico cuya rigidez del resorte no obedece exactamente a la ley de Hooke.
#
# La ecuación de Duffing es un ejemplo de un sistema dinámico que exhibe un comportamiento caótico . Además, el sistema Duffing presenta en la respuesta de frecuencia el fenómeno de resonancia de salto que es una especie de comportamiento de histéresis de frecuencia.

# %% [markdown]
# #### Parámetros
#
# Los parámetros de la ecuación anterior son:
#
# - $\delta$ : Controla la cantidad de amortiguación
# - $\alpha$ : Controla la rigidez lineal
# - $\beta$ : controla la cantidad de no linealidad en la fuerza de restauración; si $\beta = 0$ la ecuación de Duffing describe un oscilador armónico simple amortiguado y forzado
# - $\omega$ : es la frecuencia angular de la fuerza impulsora periódica.
#
#
# Se puede ver que la ecuación de Duffing describe las oscilaciones de una masa unida a un resorte no lineal y un amortiguador lineal. La fuerza de restauración proporcionada por el resorte no lineal es entonces $\alpha x + \beta x^{3}$
#
# Cuando $\alpha > 0$ y $\beta > 0$ el resorte se llama resorte de endurecimiento . A la inversa $\beta < 0$, porque es un resorte ablandador (todavía con $\alpha > 0$). En consecuencia, los adjetivos endurecimiento y ablandamiento se utilizan con respecto a la ecuación de Duffing en general, dependiendo de los valores de $\beta$ (y $\alpha$)
#
# El número de parámetros en la ecuación de Duffing se puede reducir en dos a través del escalado, por ejemplo, la excursión $x$ y el tiempo $t$ se pueden escalar como: $\tau = t \sqrt{\alpha}$ y $y = \frac{x \alpha}{\gamma}$ asumiendo que $\alpha$ es positivo (son posibles otros escalados para diferentes rangos de los parámetros, o para diferentes énfasis en el problema estudiado ). Luego:
#
# $\ddot{y} + 2 \eta \dot{y} + y + \epsilon y^{3} = cos(\sigma \tau)$ Donde $\eta = \frac{\delta}{2 \sqrt{\alpha}}$, $\epsilon = \frac{\beta \gamma^{2}}{\alpha^{3}}$ y $\sigma = \frac{\omega}{\sqrt{\alpha}}$
#
# A continuación se procede a resolver el oscilador de Duffing con parámetros reducidos y variando estos parámetros pero conservando las mismas condiciones iniciales, así, al partir de una misma situación; se podrá analizar el sistema de forma más completa.

# %%
#Se importan las librerías pertinentes

import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate

# %% [markdown]
# # Sin fricción, sin rozamiento

# %%
# %pylab inline
from numpy import *


def f(y, t): 
    x=y[1]
    v=y[0]-y[0]**3 
    return array([x, v])


y0 = [1, 1] # initial condition y0 = x0 + e 
Time = np.linspace(0,16,100)

Sol = integrate.odeint(f,y0,Time)

X = Sol[0:,0]
V = Sol[0:,1]

#Grafica de La posicion
plt.plot(Time, X,color="green")
plt.title('Oscilador de Duffing Sin Friccion')
plt.ylabel("$Posicion$")
plt.legend(["$X(t)$"])
plt.xlabel('$Tiempo(Segundos)$')
plt.grid()
plt.show()

#Grafica de La Velocidad
plt.plot(Time,V,color="Orange")
plt.title('Oscilador de Duffing Sin Friccion')
plt.ylabel("$Velocidad$")
plt.legend(["$V(t)$"])
plt.xlabel('$Tiempo(Segundos)$')
plt.grid()
plt.show()

#Grafica Diagrama de Fase
plt.plot(X, V,color="Red")
plt.title('Diagrama de Fase')
plt.ylabel("$V(t)$")
plt.xlabel('$X(t)$')
plt.grid()
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %% [markdown]
# # Con fricción, sin rozamiento

# %%
# %pylab inline
from numpy import * 

#Parametros
u=0.1
A=0.32
w=1.4
# example, 

def f(y, t):        
    x=y[1]
    v=y[0]-y[0]**3-u*y[1]  
    return array([x, v])


y0 = array([1, 1]) # initial condition y0 = x0 + e 
Time = np.linspace(0,100,1000)

Sol = integrate.odeint(f,y0,Time)

X = Sol[0:,0]
V = Sol[0:,1]

#Grafica de La posicion

plt.plot(Time, X,color="green")
plt.title('Oscilador de Duffing Sin Friccion')
plt.ylabel("$Posicion$")
plt.legend(["$X(t)$"])
plt.xlabel('$Tiempo(Segundos)$')
plt.grid()
plt.show()

#Grafica de La Velocidad

plt.plot(Time,V,color="Orange")
plt.title('Oscilador de Duffing Sin Friccion')
plt.ylabel("$Velocidad$")
plt.legend(["$V(t)$"])
plt.xlabel('$Tiempo(Segundos)$')
plt.grid()
plt.show()

#Grafica Diagrama de Fase

plt.plot(X, V,color="Red")
plt.title('Diagrama de Fase')
plt.ylabel("$V(t)$")
plt.xlabel('$X(t)$')
plt.grid()
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %% [markdown]
# # Forzado,Sin friccion

# %%
# %pylab inline
from numpy import * 

#Parametros
u=0.1
A=0.32
w=1.4
# example,  
def f(y, t):        
    x=y[1]
    v=y[0]-y[0]**3+A*np.cos(w*t)  
    return array([x, v])


y0 = array([1, 1]) # initial condition y0 = x0 + e 
Time = np.linspace(0,200, 10000)

Sol = integrate.odeint(f,y0,Time)

X = Sol[0:,0]
V = Sol[0:,1]

#Grafica de La posicion

plt.plot(Time, X,color="green")
plt.title('Oscilador de Duffing Sin Friccion')
plt.ylabel("$Posicion$")
plt.legend(["$X(t)$"])
plt.xlabel('$Tiempo(Segundos)$')
plt.grid()
plt.show()

#Grafica de La Velocidad

plt.plot(Time, V,color="Orange")
plt.title('Oscilador de Duffing Sin Friccion')
plt.ylabel("$Velocidad$")
plt.legend(["$V(t)$"])
plt.xlabel('$Tiempo(Segundos)$')
plt.grid()
plt.show()

#Grafica Diagrama de Fase

plt.plot(X, V,color="Red")
plt.title('Diagrama de Fase')
plt.ylabel("$V(t)$")
plt.xlabel('$X(t)$')
plt.grid()
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %% [markdown]
# # Con Friccion,Forzado

# %%
# %pylab inline
from numpy import * 

#Parametros

u=0.1
A=0.32
w=1.4

# example,  
def f(y, t):        
    x=y[1]
    v=y[0]-y[0]**3-u*y[1]+A*np.cos(w*t)  
    return array([x, v])


y0 = array([0, 0]) # initial condition y0 = x0 + e
Time = np.linspace(0,100,10000)

Sol = integrate.odeint(f,y0,Time)

X = Sol[0:,0]
V = Sol[0:,1]

#Grafica de La posicion

plt.plot(Time, X,color="green")
plt.title('Oscilador de Duffing')
plt.ylabel("$Posicion$")
plt.legend(["$X(t)$"])
plt.xlabel('$Tiempo(Segundos)$')
plt.grid()
plt.show()

#Grafica de La Velocidad

plt.plot(Time, V,color="Orange")
plt.title('Oscilador de Duffing')
plt.ylabel("$Velocidad$")
plt.legend(["$V(t)$"])
plt.xlabel('$Tiempo(Segundos)$')
plt.grid()
plt.show()

#Grafica Diagrama de Fase

plt.plot(X, V,color="Red")
plt.title('Diagrama de Fase')
plt.ylabel("$V(t)$")
plt.xlabel('$X(t)$')
plt.grid()
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +
